# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import statsmodels as sm
from statsmodels.distributions.empirical_distribution import ECDF
from scipy.stats import ks_2samp
# %matplotlib inline

# %% [markdown]
# ## Load the data and split into train/test sets

# %%
# load in the raw data
data = pd.read_csv('data/raw.csv', sep=' ', 
                   names=[
                       'duration', 
                       'done_feeding', 
                       'race', 
                       'poverty', 
                       'smoking', 
                       'alcohol', 
                       'age', 
                       'year', 
                       'education', 
                       'prenatal_care'], 
                   skipinitialspace=True)

# cast boolean fields to bools
for col in ['done_feeding', 'poverty', 'smoking', 'alcohol', 'prenatal_care']:
    data[col] = data[col].astype(bool)
    
# convert categorical data into appropriate data for regression
data['white'] = data['race'] == 1
data['black'] = data['race'] == 2

# reorder columns (to put race back to front) and clean up no longer need variables
del data['race']
cols = data.columns.tolist()
cols = cols[:2] + cols[-2:] + cols[2:-2]
data = data[cols]
del cols

# %%
data
# Out:
#     duration done_feeding  white  black poverty smoking alcohol  age  year  \
# 0         16         True   True  False   False   False    True   24    82
# 1          1         True   True  False   False    True   False   26    85
# 2          4        False   True  False   False   False   False   25    85
# 3          3         True   True  False   False    True    True   21    85
# 4         36         True   True  False   False    True   False   22    82
# 5         36         True   True  False   False   False   False   18    82
# 6         16         True   True  False    True    True   False   20    81
# 7          8        False   True  False   False    True   False   24    85
# 8         20         True   True  False    True   False   False   24    85
# 9         44         True   True  False   False   False   False   24    82
# 10        20         True   True  False   False    True   False   26    84
# 11        30         True   True  False   False    True   False   22    84
# 12        24         True   True  False   False   False   False   19    83
# 13        13         True   True  False   False   False   False   22    80
# 14         6         True   True  False   False   False   False   27    84
# 15         2         True   True  False   False   False   False   22    81
# 16         5         True   True  False   False   False   False   26    85
# 17       192         True   True  False   False   False   False   21    78
# 18         4         True   True  False   False   False   False   20    83
# 19        12         True   True  False   False    True   False   22    81
# 20         4         True  False   True   False   False   False   24    86
# 21        16        False  False   True    True    True    True   21    84
# 22        24         True   True  False   False   False   False   27    84
# 23        16         True   True  False   False    True   False   23    81
# 24         3         True   True  False   False   False   False   26    84
# 25        16         True   True  False   False    True   False   24    82
# 26        28         True   True  False   False   False   False   23    81
# 27         1         True   True  False   False    True   False   19    81
# 28        13         True   True  False   False   False    True   23    85
# 29        36         True   True  False   False   False   False   21    83
# 30        32         True   True  False   False    True   False   20    82
# 31        16         True   True  False   False    True    True   21    80
# 32         2         True   True  False   False   False    True   21    83
# 33         8         True   True  False   False   False    True   24    83
# 34         1         True   True  False   False   False   False   22    83
# 35        24         True  False   True   False   False   False   18    79
# 36        64         True   True  False   False    True   False   20    84
# 37         8         True   True  False   False   False   False   23    84
# 38         2         True   True  False   False   False   False   16    80
# 39        12         True   True  False   False   False   False   22    80
# 40        18         True   True  False   False   False   False   24    83
# 41        32         True   True  False   False   False   False   24    85
# 42         2         True   True  False   False   False   False   19    78
# 43         7         True   True  False   False   False   False   26    85
# 44         5         True   True  False   False   False   False   22    81
# 45        44         True   True  False   False   False   False   22    82
# 46         2         True   True  False    True    True   False   21    81
# 47         4         True   True  False   False    True   False   18    81
# 48         2        False   True  False   False   False   False   21    86
# 49         6         True   True  False   False   False   False   25    85
# 50         4         True   True  False   False   False   False   22    81
# 51        36         True   True  False   False   False   False   24    83
# 52        12         True   True  False   False   False   False   22    83
# 53        24         True   True  False   False   False   False   20    85
# 54        42         True   True  False   False   False   False   25    82
# 55        16         True   True  False   False    True   False   21    79
# 56        44         True   True  False   False   False   False   25    84
# 57        44         True   True  False   False   False   False   26    84
# 58        10         True   True  False   False   False   False   22    83
# 59         4         True   True  False    True   False   False   20    81
#          ...          ...    ...    ...     ...     ...     ...  ...   ...
#
#     education prenatal_care
# 0          14         False
# 1          12         False
# 2          12         False
# 3           9         False
# 4          12         False
# 5          11         False
# 6           9         False
# 7          12         False
# 8          12         False
# 9          14         False
# 10         12         False
# 11         12          True
# 12         12         False
# 13         14         False
# 14         16         False
# 15         12          True
# 16         13         False
# 17         12         False
# 18         12         False
# 19         12         False
# 20         12         False
# 21         12          True
# 22         14         False
# 23         12         False
# 24         14         False
# 25         14         False
# 26         12         False
# 27         12         False
# 28         14         False
# 29         10         False
# 30         12          True
# 31         12         False
# 32         12         False
# 33         14          True
# 34         10         False
# 35         11         False
# 36         12         False
# 37         10          True
# 38          9          True
# 39         13         False
# 40         12         False
# 41         14         False
# 42         12         False
# 43         16         False
# 44         12         False
# 45         16         False
# 46         12          True
# 47         10          True
# 48         12          True
# 49         16         False
# 50         12         False
# 51         12         False
# 52         13          True
# 53         12         False
# 54         16         False
# 55         13         False
# 56         12         False
# 57         16         False
# 58         12         False
# 59         11         False
#           ...           ...
#
# [927 rows x 11 columns]

# %%
# save a copy of this data
data.to_csv('data/processed.csv')

# %%
# first independence check

censored = data[~data['done_feeding']]
uncensored = data[data['done_feeding']]
ks_2samp(censored['duration'], uncensored['duration'])
# Out:
# (0.28757206918641898, 0.0058164240181803866)

# %%
# compare the CDFs

un_ecdf = ECDF(uncensored['duration'])
censored_ecdf = ECDF(censored['duration'])
plt.plot(un_ecdf.x, un_ecdf.y, censored_ecdf.x, censored_ecdf.y)
# Out:
# [<matplotlib.lines.Line2D at 0x4a98110>,
#  <matplotlib.lines.Line2D at 0x4a98210>]

# %%
# build a train and test set

# set the seed so code can be repeated
np.random.seed(2014)

# create a test set of 100 mothers (all of which are uncensored)
test_idxs = np.sort(np.random.choice(data['done_feeding'].nonzero()[0], size=100, replace=False))

# partition data into test and train
test_set = data.iloc[test_idxs]
train_set = data.iloc[~data.index.isin(test_idxs)]

# save to file
test_set.to_csv('data/test.csv')
train_set.to_csv('data/train.csv')
