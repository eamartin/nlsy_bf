# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import patsy
import statsmodels as sm
from statsmodels.distributions.empirical_distribution import ECDF
from scipy.stats import ks_2samp
import lifelines as ll
from lifelines.statistics import logrank_test, multivariate_logrank_test
# %matplotlib inline

# %% [markdown]
# ## Load the data and split into train/test sets

# %%
# load in the raw data
data = pd.read_csv('data/raw.csv', sep=' ', 
                   names=[
                       'duration', 
                       'done_feeding', 
                       'race', 
                       'poverty', 
                       'smoking', 
                       'alcohol', 
                       'age', 
                       'year', 
                       'education', 
                       'prenatal_care'], 
                   skipinitialspace=True)

# cast boolean fields to bools
for col in ['done_feeding', 'poverty', 'smoking', 'alcohol', 'prenatal_care']:
    data[col] = data[col].astype(bool)
    
for col in ['age', 'year', 'education']:
    data[col] -= data[col].min()
    
# convert categorical data into appropriate data for regression
data['white'] = data['race'] == 1
data['black'] = data['race'] == 2

# reorder columns (to put race back to front) and clean up no longer need variables
del data['race']
cols = data.columns.tolist()
cols = cols[:2] + cols[-2:] + cols[2:-2]
data = data[cols]
del cols

# %%
data
# Out:
#     duration done_feeding  white  black poverty smoking alcohol  age  year  \
# 0         16         True   True  False   False   False    True    9     4
# 1          1         True   True  False   False    True   False   11     7
# 2          4        False   True  False   False   False   False   10     7
# 3          3         True   True  False   False    True    True    6     7
# 4         36         True   True  False   False    True   False    7     4
# 5         36         True   True  False   False   False   False    3     4
# 6         16         True   True  False    True    True   False    5     3
# 7          8        False   True  False   False    True   False    9     7
# 8         20         True   True  False    True   False   False    9     7
# 9         44         True   True  False   False   False   False    9     4
# 10        20         True   True  False   False    True   False   11     6
# 11        30         True   True  False   False    True   False    7     6
# 12        24         True   True  False   False   False   False    4     5
# 13        13         True   True  False   False   False   False    7     2
# 14         6         True   True  False   False   False   False   12     6
# 15         2         True   True  False   False   False   False    7     3
# 16         5         True   True  False   False   False   False   11     7
# 17       192         True   True  False   False   False   False    6     0
# 18         4         True   True  False   False   False   False    5     5
# 19        12         True   True  False   False    True   False    7     3
# 20         4         True  False   True   False   False   False    9     8
# 21        16        False  False   True    True    True    True    6     6
# 22        24         True   True  False   False   False   False   12     6
# 23        16         True   True  False   False    True   False    8     3
# 24         3         True   True  False   False   False   False   11     6
# 25        16         True   True  False   False    True   False    9     4
# 26        28         True   True  False   False   False   False    8     3
# 27         1         True   True  False   False    True   False    4     3
# 28        13         True   True  False   False   False    True    8     7
# 29        36         True   True  False   False   False   False    6     5
# 30        32         True   True  False   False    True   False    5     4
# 31        16         True   True  False   False    True    True    6     2
# 32         2         True   True  False   False   False    True    6     5
# 33         8         True   True  False   False   False    True    9     5
# 34         1         True   True  False   False   False   False    7     5
# 35        24         True  False   True   False   False   False    3     1
# 36        64         True   True  False   False    True   False    5     6
# 37         8         True   True  False   False   False   False    8     6
# 38         2         True   True  False   False   False   False    1     2
# 39        12         True   True  False   False   False   False    7     2
# 40        18         True   True  False   False   False   False    9     5
# 41        32         True   True  False   False   False   False    9     7
# 42         2         True   True  False   False   False   False    4     0
# 43         7         True   True  False   False   False   False   11     7
# 44         5         True   True  False   False   False   False    7     3
# 45        44         True   True  False   False   False   False    7     4
# 46         2         True   True  False    True    True   False    6     3
# 47         4         True   True  False   False    True   False    3     3
# 48         2        False   True  False   False   False   False    6     8
# 49         6         True   True  False   False   False   False   10     7
# 50         4         True   True  False   False   False   False    7     3
# 51        36         True   True  False   False   False   False    9     5
# 52        12         True   True  False   False   False   False    7     5
# 53        24         True   True  False   False   False   False    5     7
# 54        42         True   True  False   False   False   False   10     4
# 55        16         True   True  False   False    True   False    6     1
# 56        44         True   True  False   False   False   False   10     6
# 57        44         True   True  False   False   False   False   11     6
# 58        10         True   True  False   False   False   False    7     5
# 59         4         True   True  False    True   False   False    5     3
#          ...          ...    ...    ...     ...     ...     ...  ...   ...
#
#     education prenatal_care
# 0          11         False
# 1           9         False
# 2           9         False
# 3           6         False
# 4           9         False
# 5           8         False
# 6           6         False
# 7           9         False
# 8           9         False
# 9          11         False
# 10          9         False
# 11          9          True
# 12          9         False
# 13         11         False
# 14         13         False
# 15          9          True
# 16         10         False
# 17          9         False
# 18          9         False
# 19          9         False
# 20          9         False
# 21          9          True
# 22         11         False
# 23          9         False
# 24         11         False
# 25         11         False
# 26          9         False
# 27          9         False
# 28         11         False
# 29          7         False
# 30          9          True
# 31          9         False
# 32          9         False
# 33         11          True
# 34          7         False
# 35          8         False
# 36          9         False
# 37          7          True
# 38          6          True
# 39         10         False
# 40          9         False
# 41         11         False
# 42          9         False
# 43         13         False
# 44          9         False
# 45         13         False
# 46          9          True
# 47          7          True
# 48          9          True
# 49         13         False
# 50          9         False
# 51          9         False
# 52         10          True
# 53          9         False
# 54         13         False
# 55         10         False
# 56          9         False
# 57         13         False
# 58          9         False
# 59          8         False
#           ...           ...
#
# [927 rows x 11 columns]

# %%
data.describe()
# Out:
#          duration done_feeding      white      black    poverty    smoking  \
# count  927.000000          927        927        927        927        927
# mean    16.176915    0.9622438  0.7141316  0.1262136   0.184466  0.2912621
# std     17.920661     0.190709  0.4520709  0.3322692  0.3880731  0.4545893
# min      1.000000        False      False      False      False      False
# 25%      4.000000            1          0          0          0          0
# 50%     10.000000            1          1          0          0          0
# 75%     24.000000            1          1          0          0          1
# max    192.000000         True       True       True       True       True
#
#           alcohol         age        year   education prenatal_care
# count         927  927.000000  927.000000  927.000000           927
# mean   0.08522114    6.539374    3.974110    9.207120     0.1769148
# std     0.2793612    2.686321    2.139159    1.928034     0.3818026
# min         False    0.000000    0.000000    0.000000         False
# 25%             0    5.000000    2.000000    9.000000             0
# 50%             0    6.000000    4.000000    9.000000             0
# 75%             0    8.000000    6.000000   10.000000             0
# max          True   13.000000    8.000000   16.000000          True
#
# [8 rows x 11 columns]

# %%
# save a copy of this data
data.to_csv('data/processed.csv')

# %%
# first independence check

censored = data[~data['done_feeding']]
uncensored = data[data['done_feeding']]
ks_2samp(censored['duration'], uncensored['duration'])
# Out:
# (0.28757206918641898, 0.0058164240181803866)

# %%
# compare the CDFs

un_ecdf = ECDF(uncensored['duration'])
censored_ecdf = ECDF(censored['duration'])
plt.plot(un_ecdf.x, un_ecdf.y, censored_ecdf.x, censored_ecdf.y)
# Out:
# [<matplotlib.lines.Line2D at 0x55e8250>,
#  <matplotlib.lines.Line2D at 0x55e8350>]

# %%
# build a train and test set

# set the seed so code can be repeated
np.random.seed(2014)

# create a test set of 100 mothers (all of which are uncensored)
test_idxs = np.sort(np.random.choice(data['done_feeding'].nonzero()[0], size=100, replace=False))

# partition data into test and train
test_set = data.iloc[test_idxs]
train_set = data.iloc[~data.index.isin(test_idxs)]

# save to file
test_set.to_csv('data/test.csv')
train_set.to_csv('data/train.csv')

# %% [markdown]
# # Actual statistical analysis now

# %%
kmf = ll.KaplanMeierFitter()
kmf.fit(train_set.duration, event_observed=train_set.done_feeding)
kmf.plot()

# %%
# work around for lifelines bug
train_set = pd.read_csv('data/train.csv')
del train_set[train_set.columns[0]]

aaf = ll.AalenAdditiveFitter(penalizer=10)
aaf.fit(train_set, duration_col='duration', event_col='done_feeding')
# Out:
#  [--                7%                  ] 56 of 792 complete in 0.5 sec
#  [--------------   37%                  ] 294 of 792 complete in 1.0 sec
#  [-----------------85%------------      ] 675 of 792 complete in 1.5 sec
#  [-----------------100%-----------------] 792 of 792 complete in 1.7 sec
# <lifelines.AalenAdditiveFitter: fitted with 827 observations, 35 censored>

# %% [markdown]
# # Testing Points

# %%
# read in the test data with appropriate index
test_set = pd.read_csv('data/test.csv', index_col=0)

# %%
# predict for the first point

tst = test_set[test_set.columns[2:]].irow(1).astype(int).values[None, :]
aaf.predict_survival_function(tst).plot()

del tst

# %%
# predict cumulative hazard functions for all points in test set
test_factors = test_set[test_set.columns[2:]].astype(int).as_matrix();
guesses = pd.DataFrame({'prediction': aaf.predict_median(test_factors), 'actual': test_set.duration}, index=test_set.index);

guesses


errors = guesses['actual'] - guesses['prediction'];

print ((errors * errors).sum() / len(errors)) ** .5
aaf.predict_survival_function(test_factors).plot(legend=False)
# TODO: evaluate performance with some metric
# Out:
# "\n\nerrors = guesses['actual'] - guesses['prediction'];\n\nprint ((errors * errors).sum() / len(errors)) ** .5\naaf.predict_survival_function(test_factors).plot(legend=False)\n# TODO: evaluate performance with some metric\n"

# %%
aaf.predict_median(test_factors)
# Out:
# 0     12
# 1     12
# 2     24
# 3      8
# 4     10
# 5      8
# 6     12
# 7     20
# 8      8
# 9     24
# 10     8
# 11     8
# 12     8
# 13     8
# 14    12
# ...
# 85    16
# 86    21
# 87    16
# 88    12
# 89    16
# 90    10
# 91    12
# 92    13
# 93    24
# 94    16
# 95    16
# 96    12
# 97    16
# 98    12
# 99     8
# Length: 100, dtype: float64

# %%
aaf.cumulative_hazards_.plot()

# %% [markdown]
# ## Eric's factor analysis

# %%
# binary variables
T = data.duration
C = data.done_feeding
for s in ['poverty', 'smoking', 'alcohol', 'prenatal_care']:
    ix = data[s]
    p = logrank_test(data.duration[ix], data.duration[~ix], data.done_feeding[ix], data.done_feeding[~ix])[1]
    kmf.fit(T[ix], C[ix], label=s)
    ax = kmf.plot()
    kmf.fit(T[~ix], C[~ix], label='not %s' % s)
    kmf.plot(ax=ax)
    plt.title('p-value %f' % p)

# categorical test
race = 2 * data.white.values + data.black.values
p = multivariate_logrank_test(data.duration.values, race, data.done_feeding.values)[1]
kmf.fit(T[data.white], C[data.white], label='white')
ax = kmf.plot()
kmf.fit(T[data.black], C[data.black], label='black')
ax = kmf.plot(ax=ax)
kmf.fit(T[~data.white & ~data.black], C[~data.white & ~data.black], label='other')
kmf.plot(ax=ax)
plt.title('p-value %f' % p)

# continuous tests
for s in ['age', 'year', 'education']:
    ix = data[s] < data[s].median()
    p = logrank_test(data.duration[ix], data.duration[~ix], data.done_feeding[ix], data.done_feeding[~ix])[1]
    kmf.fit(T[ix], C[ix], label='lesser %s' % s)
    ax = kmf.plot()
    kmf.fit(T[~ix], C[~ix], label='greater %s' % s)
    kmf.plot(ax=ax)
    plt.title('p-value %f' % p)

# %% [markdown]
# So smoking is the greatest factor... Let's adjust for that now.

# %%
aaf.fit(data[['duration', 'done_feeding', 'smoking']], duration_col='duration', event_col='smoking')
# Out:
#  [-----------------100%-----------------] 270 of 270 complete in 0.2 sec
# <lifelines.AalenAdditiveFitter: fitted with 927 observations, 657 censored>

# %%
aaf.predict_survival_function(np.array([[0],[1]])).plot()

# %%
covariates = data['smoking'].values
smoking_factor = aaf.predict_expectation(np.array([[0], [1]]))
# advantage of not smoking over smoking
smoking_factor = smoking_factor[0] - smoking_factor[1]

# binary variables
T = data.duration + smoking_factor * data.smoking
C = data.done_feeding
for s in ['poverty', 'alcohol', 'prenatal_care']:
    ix = data[s]
    p = logrank_test(T[ix], T[~ix], C[ix], C[~ix])[1]
    kmf.fit(T[ix], C[ix], label=s)
    ax = kmf.plot()
    kmf.fit(T[~ix], C[~ix], label='not %s' % s)
    kmf.plot(ax=ax)
    plt.title('p-value %f' % p)

# categorical test
race = 2 * data.white.values + data.black.values
p = multivariate_logrank_test(T.values, race, C.values)[1]
kmf.fit(T[data.white], C[data.white], label='white')
ax = kmf.plot()
kmf.fit(T[data.black], C[data.black], label='black')
ax = kmf.plot(ax=ax)
kmf.fit(T[~data.white & ~data.black], C[~data.white & ~data.black], label='other')
kmf.plot(ax=ax)
plt.title('p-value %f' % p)

# continuous tests
for s in ['age', 'year', 'education']:
    ix = data[s] < data[s].median()
    p = logrank_test(T[ix], T[~ix], C[ix], C[~ix])[1]
    kmf.fit(T[ix], C[ix], label='lesser %s' % s)
    ax = kmf.plot()
    kmf.fit(T[~ix], C[~ix], label='greater %s' % s)
    kmf.plot(ax=ax)
    plt.title('p-value %f' % p)
